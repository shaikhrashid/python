# %%
x = 5
y = 6
z = x*y
print("First number is ", x)
print("Second number is", y)
print("Product of two numbers is ", z)
print("Product of ", x, " and ", y, " is ", z)
# Out:
# First number is  5
# Second number is 6
# Product of two numbers is  30
# Product of  5  and  6  is  30

# %%
#subtract 2 numbers

x = 9
y = 5
z = x-y
print (z)
print ("The subtraction of " , x, " and " ,y, " is " , z )
# Out:
# 4
# The subtraction of  9  and  5  is  4

# %%
x = 7
y = 8
z = x + y
print(x)
print(y)
print(z)

print ("The addition of " , x, " and ", y , " is " , z)
# Out:
# 7
# 8
# 15
# The addition of  7  and  8  is  15

# %%
#swapping of two numbers with temp variable
x = 7
y = 8
print("Before swapping")
print("The value of x = ", x)
print("The value of y = ", y)

z = x
x = y
y = z
print("After swapping")
print("The value of x = ", x)
print("The value of y = ", y)
# Out:
# Before swapping
# The value of x =  7
# The value of y =  8
# After swapping
# The value of x =  8
# The value of y =  7

# %%
#swapping of two numbers without temp variable

x = 7
y = 8
print("Before swapping")
print("The value of x = ", x)
print("The value of y = ", y)

x = x+y   #x = 15
y = x-y   #y = 7
x = x-y   #x = 8

print("After swapping")
print("The value of x = ", x)
print("The value of y = ", y)
# Out:
# Before swapping
# The value of x =  7
# The value of y =  8
# After swapping
# The value of x =  8
# The value of y =  7

# %%
#if else example
name = 'Rashid'
if(name == 'Arshad'):
  print("This is Arshad")
else:
  print('This is someone else')
# Out:
# This is someone else

# %%
# mod and div (% and /)
# % => always gives the remainder

y = 7
z = 7%2
x = int(7/2)
print(z)
print (x)
# Out:
# 1
# 3

# %%
#div for floats/double. It will return value with decimal values

x = 10
y = 10%3
z = 10/3
print (y)
print (z)
# Out:
# 1
# 3.3333333333333335

# %%
#find the number is odd or even
#find if the number is divisible by 2

x = 10
if x%2 == 0:
  print("The number is even")
else:
  print("The number is odd")
# Out:
# The number is even

# %%
#To check is the number is divisible by 5

x = 45
if x%5 == 0:
  print("The number is divisbile by 5")
else:
  print("The number is not divisbile by 5")
# Out:
# The number is divisbile by 5

# %%
#To find which number is greater among two numbers

x = 48
y = 24
if x>y:
  print("X is greater")
else:
  print("y is greater")
# Out:
# X is greater

# %%
#To find which number is greater among three numbers

x = 10
y = 20
z = 30
if x>y>z:
  print("x is greater than y and z")
elif y>x>z:
  print("y is greater than z and x")
else:
  print("z is greater than x and y")
# Out:
# z is greater than x and y

# %%
#Find the square of number
x = 5
y = x*x
print(y)
# Out:
# 25

# %%
#Find the cube of number
x = 6
y = x*x*x
print("The cuber of ", x, " is ", y)
# Out:
# The cuber of  6  is  216

# %%
#Maths = 80, Science = 75, English = 98. Find the percentage of the student when the total marks is 300

maths = 80
science = 75
english = 98
total = maths + science + english
percentage = total/300*100
print("The total marks is ", total)
print("The percentage is ", percentage, "%")
# Out:
# The total marks is  253
# The percentage is  84.33333333333334 %

# %%
#Rajesh  a cycle on 25000 and sold at 30000. Identify if it is a profit or loss

cost_price = 25000
selling_price = 30000
profit = selling_price - cost_price
if profit > 0:
  print("It is a profit of ", profit)
else:
  print("IT is a loss of ", profit)
# Out:
# It is a profit of  5000

# %%
""" Question: Consider two numbers. Perform their subtraction and if the result of subtraction is greater than
25, print their multiplication result else print their division result. """

x = 10
y = 5
z = x - y 
if z > 25:
  print("The product of ", x, " and ", y, " is ", x*y)
else:
  print("The division of ", x, " by ", y, " is ", x/y)
# Out:
# The division of  10  by  5  is  2.0

# %%
#Check if the 2 numbers are same or not

x = 3
y = 2
if x==y:
  print("The ", x, " and ", y, " are same")
else:
  print("The ", x, " and ", y, " are not same")
# Out:
# The  3  and  2  are not same

# %%
#Working with input

birth_year = input( "Enter your birth year: " )
age = int (2021) - int (birth_year)
print (age)
# Out:
# Enter your birth year: 1996
# 25

# %%
a = input("Please enter your name ")
print("Entered name is ", a)
# Out:
# Please enter your name Rashid
# Entered name is  Rashid
